# %% [markdown]
# # Importing libraries

# %%
import warnings
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
import statsmodels.api as sm

# %% [markdown]
# # Importing dataset

# %%
dataset = pd.read_csv('Sales_data.csv')

# %%
# look into dataset structure
dataset.head()
# Out:
#          Date  Sales  Units  Stock      SKU    Retailer
# 0  2014-02-06    0.0    NaN   -0.0  SKU_126  RETAILER_5
# 1  2014-02-06    0.0    NaN    0.0  SKU_126  RETAILER_6
# 2  2014-02-06    0.0    NaN    0.0  SKU_126  RETAILER_7
# 3  2014-02-06    0.0    NaN    0.0  SKU_126  RETAILER_8
# 4  2014-02-06    0.0    NaN    0.0  SKU_127  RETAILER_0

# %% [markdown]
# # Data preprocessing

# %%
# find min. and max. dates in 'Date' column
dataset['Date'].min(), dataset['Date'].max()
# Out:
# ('2014-02-06', '2017-10-19')

# %%
# Since 'Sales_data.csv' contains additional columns Units, Stock, SKU and Retailer
# and there is no information on their influence on sales, they are not concidered on further model building process
# negative values in sales column remained, assuming they reflect product rerurns by customer
X = dataset.iloc[:, 0:2]

# %%
len(X)
# Out:
# 114199

# %%
X.tail()
# Out:
#               Date  Sales
# 114194  2017-10-19    0.0
# 114195  2017-10-19   -0.9
# 114196  2017-10-19    0.0
# 114197  2017-10-19    0.0
# 114198  2017-10-19    0.0

# %%
# check how many columns have nan values
X.isnull().sum()
# Out:
# Date     0
# Sales    0
# dtype: int64

# %%
# since task is to predict sales for next 6 months, the sales data is groupped by Date
X = X.groupby('Date')['Sales'].sum().reset_index()

# %%
X
# Out:
#            Date      Sales
# 0    2014-02-06  272996.20
# 1    2014-02-13  346172.76
# 2    2014-02-20  423308.32
# 3    2014-02-27  387812.84
# 4    2014-03-05  528118.23
# ..          ...        ...
# 189  2017-09-21  504333.40
# 190  2017-09-28  490658.09
# 191  2017-10-05  471625.42
# 192  2017-10-12  448425.58
# 193  2017-10-19  489885.29
#
# [194 rows x 2 columns]

# %%
# fill in nan values in case if any with 0
X.fillna(X.dtypes.replace({'float64': 0.0}), downcast='infer', inplace=True)

# %%
# change values to date time in columns with date
format = '%Y-%m-%d %H:%M:%S'
X['Date'] = pd.to_datetime(X['Date'] + ' 00:00:00', format=format)
X = X.set_index(pd.DatetimeIndex(X['Date']))

# %%
# remove duplicates 'Date' column
X = X.drop('Date', 1)
# Out:
# <ipython-input-14-44f36e5438dc>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X = X.drop('Date', 1)

# %%
# since task is to make predictions for next 6 months and since current date data is patchy
# average daily sales value for month will be used, and start of each month is used as timestamp
y = X['Sales'].resample('MS').mean()

# %%
y['2014']
# Out:
# Date
# 2014-02-01    357572.5300
# 2014-03-01    545586.2550
# 2014-04-01    425795.8260
# 2014-05-01    515080.1250
# 2014-06-01    662039.0300
# 2014-07-01    576231.1880
# 2014-08-01    669782.2150
# 2014-09-01    449120.1025
# 2014-10-01    398807.1140
# 2014-11-01    433800.2075
# 2014-12-01    438041.5960
# Freq: MS, Name: Sales, dtype: float64

# %% [markdown]
# # Visualizing the Sales Time Series Data

# %%
# plot and display our dataset
y.plot(figsize=(14, 7))
plt.show()

# %%
# since data shows obvious seasonality, whith decrease of sales starting from September and continues 
# up untill March (which happens in industries like icecream production or agriculture),
# it would be good to visualize separatly data in terms of seasonality, trend and noise
# such visualization implemented with time-series decomposition method

# set chart size
rcParams['figure.figsize'] = 18, 9
# using time-series decomposition method, build charts
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# Above provided charts, proves that company's sales show continues positive growth dynamics, with clear seasonality.

# %% [markdown]
# ## Time series forecasting with ARIMA

# %%
# time-series forecasting done with ARIMA method
# set range for ARIMA model parameters
p = d = q = range(0, 2)
# generate the list of parameters combinations
pdq = list(itertools.product(p, d, q))
# generate the list of seasonal parameters combinations
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
# display the examples of generated combinations
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
# find optimal set of parameters (combinations) that wil give best model performance using grid search

warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit(maxiter=200)
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1289.1262043298486
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:3022678.4418283585
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:772.3314040252706
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:481.5224833177911
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:787.5348963557394
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:771.2493409533593
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:504.08251605931457
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:477.03081824299267
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1231.0407095197904
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2724935.9050339437
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:740.7322835462868
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:456.2596596218445
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:937.8139742642392
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:883.3396652390982
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:502.30379634595323
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:451.71849055494965
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1113.0878650470188
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:117492.73248511615
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:749.554204772183
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:457.49164349143507
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:768.5648800078145
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:117076.95246160276
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:478.48442730654585
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:457.5435002261984
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1086.9130563190395
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:90431.6590733181
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:719.4436874463239
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:430.8186358207385
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:802.5024951262828
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:102767.80890524201
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:476.3365140372466
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:429.579442528745
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1143.2041272823703
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:151711.57014717654
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:763.1012973121865
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:477.68348385069675
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:805.9082833149791
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:808.1823664241294
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:476.50087889177985
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:473.72711221887863
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1114.072577114007
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:111932.71835661864
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:738.564600954402
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:452.6214504581621
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:804.9256735707053
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:781.6853202801502
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:471.93698719446445
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:450.1474320360548
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1112.7177940291422
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:99067.909785204
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:745.3482025780902
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:456.8928629734545
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:778.7679695590197
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:98847.98110809873
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:455.0054721927449
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:456.2609937417247
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1076.8180756930458
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:85949.79975239991
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:721.3215958681898
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:432.724267129918
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:779.1913305288982
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:85893.16317674046
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:453.6590486993897
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:431.42515867521155

# %% [markdown]
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:429.579442528745 is the optimal AIC value for our model

# %% [markdown]
# ## Fitting the ARIMA model

# %%
# run data series analysis with Seasonal AutoRegressive Integrated Moving Average with eXogenous regressors model
# and display the results in table
mod = sm.tsa.statespace.SARIMAX(y, order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), enforce_stationarity=False,
                               enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6321      0.252     -2.507      0.012      -1.126      -0.138
# ar.S.L12      -0.4903      0.318     -1.544      0.123      -1.113       0.132
# ma.S.L12       0.2150      0.570      0.377      0.706      -0.901       1.331
# sigma2       1.19e+09   3.84e-11    3.1e+19      0.000    1.19e+09    1.19e+09
# ==============================================================================
# C:\Users\aurum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
# to check for any unusual model behaviour, make model diagnostics and display the results
results.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-cade9f4641de> in <module>
#       1 # to check for any unusual model behaviour, make model diagnostics and display the results
# ----> 2 results.plot_diagnostics(figsize=(16, 8))
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in plot_diagnostics(self, variable, lags, fig, figsize, truncate_endog_names)
#    4282
#    4283         if resid.shape[0] < max(d, lags):
# -> 4284             raise ValueError(
#    4285                 "Length of endogenous variable must be larger the the number "
#    4286                 "of lags used in the model and the number of observations "
#
# ValueError: Length of endogenous variable must be larger the the number of lags used in the model and the number of observations burned in the log-likelihood calculation.

# %% [markdown]
# ## Validating forecasts

# %%
type(results)
# Out:
# statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper

# %%
# to compare accuracy of model predictions, run comparizon of real data and predicted, 
# starting from '2017-02-01'
pred = results.get_prediction(start=pd.to_datetime('2017-02-01'), end=pd.to_datetime('2017-10-19'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2014':].plot(label='Historical data')
pred.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# Acording to the plot illustration, model predictions goes very closely to the actual data, capturing seasonality of the sales.

# %%
# calculate Mean Squared Error for model forecasts and display the average of squarred of errors
y_pred = pred.predicted_mean
y_pred = y_pred [:-1]
y_true = y['2017-02-01':]
mse = ((y_pred - y_true) ** 2).mean()

# %%
print(f'The Mean Squared Error of model forecasts is {round(mse, 2)}')
# Out:
# The Mean Squared Error of model forecasts is 677709939.03

# %%
print(f'The Root Mean Squared Error of model forecasts is {round(np.sqrt(mse), 2)}')
# Out:
# The Root Mean Squared Error of model forecasts is 26032.86

# %%
# calculate persentage error of our model and display the results
model_error = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
print(f'The model gives in average {round(model_error, 2)}% of errors in making forecasts comparing to actual data!')
# Out:
# The model gives in average 3.48% of errors in making forecasts comparing to actual data!

# %% [markdown]
# ## Producing and visualizing forecasts for next 6 months

# %%
pred_uc =results.get_forecast(steps=6)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color='g', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Sales')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7433086b1caf> in <module>
# ----> 1 pred_uc =results.get_forecast(steps=6)
#       2 pred_ci = pred_uc.conf_int()
#       3 ax = y.plot(label='observed', figsize=(14, 7))
#       4 pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
#       5 ax.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color='r', alpha=.25)
#
# NameError: name 'results' is not defined

# %% [markdown]
# ## Display the forecasted data for next 6 months

# %%
# make predictions for next 6 months
pred_tbl = results.forecast(steps=6)

# %%
# display results of forecasts as table
pd.DataFrame({'Projected Date':pred_tbl.index, 'Sales':pred_tbl.values})
# Out:
#   Projected Date          Sales
# 0     2017-11-01  519636.791949
# 1     2017-12-01  494013.806605
# 2     2018-01-01  447029.164535
# 3     2018-02-01  436166.362039
# 4     2018-03-01  621823.044672
# 5     2018-04-01  561262.466176
